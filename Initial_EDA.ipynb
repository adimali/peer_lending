# %%
import pandas as pd
pd.set_option('display.max_rows', 100, 'display.max_columns', 200)

# %%
# Q1_2016=pd.read_csv('LoanStats_2016Q1.csv',skiprows=[0])
# Q2_2016=pd.read_csv('LoanStats_2016Q2.csv',skiprows=[0])

data_3a=pd.read_csv('LoanStats3a.csv',skiprows=[0])
# Q2_2016=pd.read_csv('LoanStats_2016Q2.csv',skiprows=[0])
# Out:
# /home/thor/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (0,47) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data_3a
# Out:
#                                                     id  member_id  loan_amnt  \
# 0                                                  NaN        NaN     5000.0
# 1                                                  NaN        NaN     2500.0
# 2                                                  NaN        NaN     2400.0
# 3                                                  NaN        NaN    10000.0
# 4                                                  NaN        NaN     3000.0
# 5                                                  NaN        NaN     5000.0
# 6                                                  NaN        NaN     7000.0
# 7                                                  NaN        NaN     3000.0
# 8                                                  NaN        NaN     5600.0
# 9                                                  NaN        NaN     5375.0
# 10                                                 NaN        NaN     6500.0
# ...

# %%
Q1_2016.drop(['id','member_id','emp_title','revol_bal_joint','sec_app_earliest_cr_line',
              'sec_app_inq_last_6mths','sec_app_mort_acc','sec_app_open_acc',
              'sec_app_revol_util','sec_app_open_il_6m','sec_app_num_rev_accts',
              'sec_app_chargeoff_within_12_mths','sec_app_collections_12_mths_ex_med',
              'sec_app_mths_since_last_major_derog'], axis=1, inplace=True)

# %%
Q1_2016= Q1_2016[:-2]

# %%
Q1_2016.groupby(['term'])['term'].count()

# %%
Q1_2016['term']=Q1_2016['term'].replace([r'36*',r'60*'],[36,60],regex=True)

# Q1_2016.loc[Q1_2016['term'].str.contains('36',na=False),'term']=36
# Q1_2016.loc[Q1_2016['term'].str.contains('60',na=False),'term']=60

Q1_2016['int_rate'] = Q1_2016['int_rate'].replace('%','',regex=True).astype('float')/100

# %%
Q1_2016

# %%
Q1_2016[['loan_amnt','term','int_rate','installment','revol_bal','revol_util']]

# %%
Q1_2016['emp_length']=Q1_2016['emp_length'].replace([r'<1*',r'10\+*','n/a'],[0.5,11,0],regex=True)
Q1_2016['emp_length'] = Q1_2016['emp_length'].replace(r'year.*','',regex=True).astype('float')

# %%
Q1_2016.groupby(['purpose'])['purpose'].count()

# %%
Q1_2016.groupby(['loan_status'])['loan_status'].count()

# %%
Q1_2016[Q1_2016['loan_status']=='Charged Off']

# %%
Q1_2016.groupby(['mths_since_last_delinq'])['mths_since_last_delinq'].count()
